# %% [markdown]
# ### Runnable

# %%
from langchain_ollama.chat_models import ChatOllama

model = ChatOllama(model="llama3.2:3b")

completion = model.invoke("반가워요!")
# 안녕하세요! 만나서 반가워요. 무엇을 도와드릴까요?

completions = model.batch(["반가워요!", "잘 있어요!"])
# ['안녕하세요! 만나서 반가워요! 어떻게 도와드릴까요?', '감사합니다! 제가 여기 있어서 도와줄 수 있는 일이 있으면 말씀해주세요. ^^']

for token in model.stream("잘 있어요!"):
    print(token)
# 잘
# 가
# !
# Out:
# content='감' additional_kwargs={} response_metadata={} id='run--c9a16743-4a00-4b66-b506-2ae6e8606a3e'
# content='사' additional_kwargs={} response_metadata={} id='run--c9a16743-4a00-4b66-b506-2ae6e8606a3e'
# content='합니다' additional_kwargs={} response_metadata={} id='run--c9a16743-4a00-4b66-b506-2ae6e8606a3e'
# content='!' additional_kwargs={} response_metadata={} id='run--c9a16743-4a00-4b66-b506-2ae6e8606a3e'
# content='' additional_kwargs={} response_metadata={'model': 'llama3.2:3b', 'created_at': '2025-10-02T00:16:38.879759338Z', 'done': True, 'done_reason': 'stop', 'total_duration': 664982957, 'load_duration': 128308389, 'prompt_eval_count': 30, 'prompt_eval_duration': 68894798, 'eval_count': 5, 'eval_duration': 466076849, 'model_name': 'llama3.2:3b'} id='run--c9a16743-4a00-4b66-b506-2ae6e8606a3e' usage_metadata={'input_tokens': 30, 'output_tokens': 5, 'total_tokens': 35}

# %% [markdown]
# ### 명령형 구성

# %%
from langchain_ollama.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import chain

# 구성 요소
template = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 친절한 어시스턴트입니다."),
        ("human", "{question}"),
    ]
)

model = ChatOllama(model="llama3.2:3b")


# 함수로 결합한다
# 데코레이터 @chain을 추가해 작성한 함수에 Runnable 인터페이스를 추가한다
@chain
def chatbot(values):
    prompt = template.invoke(values)
    return model.invoke(prompt)


# 사용한다

response = chatbot.invoke({"question": "거대 언어 모델은 어디서 제공하나요?"})
print(response.content)
# Out:
# 가장 많이 사용되는 거대 언어 모델은 Hugging Face의 transformers와 BERT를 기반으로 한 models로,这些모델은 다양한 nguồn에서提供됩니다.
#
# 1.  **Hugging Face**: Hugging Face는 대규모 개방형 데이터셋과 다양한 모เดルの 제공을 통해 많은 researchers와 개발자들이 利用할 수 있는 거대 언어 모델을 제공합니다. Hugging Face의 Transformers library는 PyTorch에 대한 API를 제공하는(transformers)입니다.
# 2.  **Google**: Google은 BERT와 같은 거대 언어模型을 공개하여 연구를 도움이 됩니다.
# 3.  **OpenAI**: OpenAI의 GPT-3과 DALL-E가 거대 언어 모델입니다.
#
# 위의 models이 있습니다.

# %% [markdown]
# ### 명령형 구성을 사용한 스트리밍

# %%
@chain
def chatbot(values):
    prompt = template.invoke(values)
    for token in model.stream(prompt):
        yield token


for part in chatbot.stream({"question": "거대 언어 모델은 어디서 제공하나요?"}):
    print(part)
# Out:
# content='가' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='장' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='多' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='used' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Language' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Model' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='이' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 되는' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' transformer' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='-base' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='는' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' H' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='ugging' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Face' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='의' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Hub' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='에' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 있습니다' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='.' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' transformers' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=',' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' dist' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='il' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='bert' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=',' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' robert' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='a' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 등' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 많은' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 다른' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='도' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' H' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='ugging' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Face' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='의' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' Hub' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='에서' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' availability' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='합니다' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='다' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='른' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 경우' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=',' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 많은' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' API' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='와' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' library' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='에서' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 언어' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='을' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 사용' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='할' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 수' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 있' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='으니' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 해당' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' library' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='를' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 확인' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='하고' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=',' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' corresponding' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' API' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='의' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' documentation' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='를' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content=' 확인' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='하' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='십시오' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='.' additional_kwargs={} response_metadata={} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d'
# content='' additional_kwargs={} response_metadata={'model': 'llama3.2:3b', 'created_at': '2025-10-02T00:22:48.877507554Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6151553577, 'load_duration': 71588118, 'prompt_eval_count': 49, 'prompt_eval_duration': 98019846, 'eval_count': 74, 'eval_duration': 5979258939, 'model_name': 'llama3.2:3b'} id='run--5f9f0376-9527-4311-9fc5-c244c135e82d' usage_metadata={'input_tokens': 49, 'output_tokens': 74, 'total_tokens': 123}

# %% [markdown]
# ### 명령형 구성을 사용한 비동기 실행

# %%
@chain
async def chatbot(values):
    prompt = await template.ainvoke(values)
    return await model.ainvoke(prompt)


await chatbot.ainvoke({"question": "거대 언어 모델은 어디서 제공하나요?"})
# Out:
# AIMessage(content='가장 대형의 language model은 Meta AI의 transformer에 의해 개발되었습니다. 이 models는 다채로운use cases에서 사용될 수 있으며, OpenAi의 GPT-3, Hugging Face의 DistilBERT 및 others가 일부 case case에 사용됩니다.', additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2025-10-02T00:25:33.21430287Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4656539524, 'load_duration': 59473963, 'prompt_eval_count': 49, 'prompt_eval_duration': 65085947, 'eval_count': 59, 'eval_duration': 4530485644, 'model_name': 'llama3.2:3b'}, id='run--14aa44f8-4b72-4e32-b10e-8010a3142f3f-0', usage_metadata={'input_tokens': 49, 'output_tokens': 59, 'total_tokens': 108})

# %% [markdown]
# ### 선언형 구성

# %%
from langchain_ollama.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

# 구성 요소
template = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 친절한 어시스턴트입니다."),
        ("human", "{question}"),
    ]
)

model = ChatOllama(model="llama3.2:3b")

# 연산자 | 로 결합한다
chatbot = template | model

# 사용한다
response = chatbot.invoke({"question": "거대 언어 모델은 어디서 제공하나요?"})
print(response.content)
# Out:
# 지금까지 many large language models are provided by companies such as Meta, Google, and Microsoft.

# %%
# 스트리밍
chatbot = template | model

for part in chatbot.stream({"question": "거대 언어 모델은 어디서 제공하나요?"}):
    print(part)
# Out:
# content='가' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='iant' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='를' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 위한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 언어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='을' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 사용' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='할' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 수' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 있는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 다양한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 자' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='본' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='화' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='된' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' modèle' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='이' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 있습니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='음' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='은' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 몇' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 가지' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 예' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='를' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 들어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 보' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='십시오' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='1' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' **' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='H' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ugging' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Face' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Transformers' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='**:' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' H' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ugging' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Face' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Open' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' AI' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='에서' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 배' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='포' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Transformers' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='의' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 지' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='점' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='입니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 그' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='들은' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 다양한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 언어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='모' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=',' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' including' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' B' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ERT' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=',' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Ro' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='BERT' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='a' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 및' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Dist' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='il' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='BERT' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='가' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 있습니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='2' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' **' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Google' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cloud' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Natural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' API' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='**:' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Google' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cloud' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Natural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' API' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Natural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Processing' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' (' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='N' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='LP' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=')' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' tasks' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='를' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 수행' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='하는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' शक' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='력' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ful' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' API' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='입니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' \n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='3' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' **' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Microsoft' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Azure' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cognitive' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='**:' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Microsoft' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Azure' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cognitive' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='에는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' N' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='LP' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='를' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 위한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 여러' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='이' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 포함' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='되어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 있습니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' \n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='4' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' **' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Amazon' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Sage' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Maker' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='**:' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Amazon' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Sage' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Maker' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' AWS' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='에서' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 제공' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='하는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' AI' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' service' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='입니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 그것' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='은' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 다양한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' N' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='LP' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' tasks' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='를' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 수행' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='하는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Model' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='을' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 지원' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='합니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='5' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' **' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' spa' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Cy' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='**:' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' spa' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Cy' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='는' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='open' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-source' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' N' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='LP' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' library' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='로' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=',' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 다양한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 언어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='모' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='을' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' support' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='합니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='음' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='은' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 거' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='대' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 언어' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 모델' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='을' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 사용' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='하기' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 위해' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' 유' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='용' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='한' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' API' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' list' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='입니다' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='*' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' H' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ugging' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Face' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Transformers' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' [' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='h' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ugging' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='face' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.co' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/models' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='](' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='h' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ugging' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='face' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.co' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/models' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=')\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='*' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Google' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cloud' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Natural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' API' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' [' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='cloud' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.google' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='atural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='](' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='cloud' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.google' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='atural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=')\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='*' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Microsoft' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Azure' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Cognitive' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' [' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='azure' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.microsoft' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ko' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='kr' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/c' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ognitive' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='atural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-processing' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='](' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='azure' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.microsoft' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ko' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='kr' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/c' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='ognitive' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-services' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='atural' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-language' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='-processing' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/)\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='*' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Amazon' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' Sage' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Maker' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' [' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='aws' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.amazon' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/s' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='agem' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='aker' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='](' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='aws' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.amazon' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.com' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/s' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='agem' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='aker' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/)\n' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='*' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' spa' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='Cy' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=':' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content=' [' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='sp' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='acy' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.io' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='](' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='https' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='://' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='sp' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='acy' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='.io' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='/)' additional_kwargs={} response_metadata={} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8'
# content='' additional_kwargs={} response_metadata={'model': 'llama3.2:3b', 'created_at': '2025-10-02T00:30:05.97587359Z', 'done': True, 'done_reason': 'stop', 'total_duration': 35008653818, 'load_duration': 83719904, 'prompt_eval_count': 49, 'prompt_eval_duration': 80263547, 'eval_count': 347, 'eval_duration': 34842477049, 'model_name': 'llama3.2:3b'} id='run--ed4ee16d-d949-4418-9e85-b35dac894fc8' usage_metadata={'input_tokens': 49, 'output_tokens': 347, 'total_tokens': 396}

# %%
# 비동기 실행
chatbot = template | model

await chatbot.ainvoke({"question": "거대 언어 모델은 어디서 제공하나요?"})
